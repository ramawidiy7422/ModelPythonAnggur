# %%
# Import Data Science Libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
import itertools
import random

# Import visualization libraries
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import cv2

# Tensorflow Libraries
from tensorflow import keras
from tensorflow.keras import layers,models
from keras_preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import Callback, EarlyStopping,ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import Model
from tensorflow.keras.layers.experimental import preprocessing

# System libraries
from pathlib import Path
import os.path

# Metrics
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Import series of helper functions for our notebook
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, compare_historys, walk_through_dir, pred_and_plot

# %%
# Walk through each directory
dataset = "baru"
walk_through_dir(dataset)
# Out:
# There are 2 directories and 0 images in 'baru'.
# There are 5 directories and 0 images in 'baru\Training'.
# There are 0 directories and 888 images in 'baru\Training\BercakHitam'.
# There are 0 directories and 869 images in 'baru\Training\BukanDaunAnggur'.
# There are 0 directories and 814 images in 'baru\Training\DaunSehat'.
# There are 0 directories and 828 images in 'baru\Training\HawarDaun'.
# There are 0 directories and 855 images in 'baru\Training\KaratDaun'.
# There are 5 directories and 0 images in 'baru\validation'.
# There are 0 directories and 192 images in 'baru\validation\BercakHitam'.
# There are 0 directories and 189 images in 'baru\validation\BukanDaunAnggur'.
# There are 0 directories and 190 images in 'baru\validation\DaunSehat'.
# There are 0 directories and 197 images in 'baru\validation\HawarDaun'.
# There are 0 directories and 184 images in 'baru\validation\KaratDaun'.

# %%
image_dir = Path(dataset)

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.JPG')) + list(image_dir.glob(r'**/*.jpg')) + list(image_dir.glob(r'**/*.png')) + list(image_dir.glob(r'**/*.PNG'))

labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# %%
import PIL
from pathlib import Path
from PIL import UnidentifiedImageError

path = Path("DatasetAnggur").rglob("*.jpg")
for img_p in path:
    try:
        img = PIL.Image.open(img_p)
    except PIL.UnidentifiedImageError:
            print(img_p)

# %%
image_df
# Out:
#                                                 Filepath        Label
# 0      baru\Training\BercakHitam\BercakHitam_color_10...  BercakHitam
# 1      baru\Training\BercakHitam\BercakHitam_color_10...  BercakHitam
# 2      baru\Training\BercakHitam\BercakHitam_color_10...  BercakHitam
# 3      baru\Training\BercakHitam\BercakHitam_color_10...  BercakHitam
# 4      baru\Training\BercakHitam\BercakHitam_color_10...  BercakHitam
# ...                                                  ...          ...
# 10337  baru\validation\KaratDaun\KaratDaun_color_3_0.jpg    KaratDaun
# 10338  baru\validation\KaratDaun\KaratDaun_color_3_1.jpg    KaratDaun
# 10339  baru\validation\KaratDaun\KaratDaun_color_3_2.jpg    KaratDaun
# 10340  baru\validation\KaratDaun\KaratDaun_color_3_3.jpg    KaratDaun
# 10341  baru\validation\KaratDaun\KaratDaun_color_9_3.jpg    KaratDaun
#
# [10342 rows x 2 columns]

# %%
# Display 16 picture of the dataset with their labels
random_index = np.random.randint(0, len(image_df), 16)
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[random_index[i]]))
    ax.set_title(image_df.Label[random_index[i]])
plt.tight_layout()
plt.show()

# %%
def compute_ela_cv(path, quality):
    temp_filename = 'temp_file_name.jpeg'
    SCALE = 15
    orig_img = cv2.imread(path)
    orig_img = cv2.cvtColor(orig_img, cv2.COLOR_BGR2RGB)
    
    cv2.imwrite(temp_filename, orig_img, [cv2.IMWRITE_JPEG_QUALITY, quality])

    # read compressed image
    compressed_img = cv2.imread(temp_filename)

    # get absolute difference between img1 and img2 and multiply by scale
    diff = SCALE * cv2.absdiff(orig_img, compressed_img)
    return diff


def convert_to_ela_image(path, quality):
    temp_filename = 'temp_file_name.jpeg'
    ela_filename = 'temp_ela.png'
    image = Image.open(path).convert('RGB')
    image.save(temp_filename, 'JPEG', quality = quality)
    temp_image = Image.open(temp_filename)

    ela_image = ImageChops.difference(image, temp_image)

    extrema = ela_image.getextrema()
    max_diff = max([ex[1] for ex in extrema])
    if max_diff == 0:
        max_diff = 1

    scale = 255.0 / max_diff
    ela_image = ImageEnhance.Brightness(ela_image).enhance(scale)
    
    return ela_image


def random_sample(path, extension=None):
    if extension:
        items = Path(path).glob(f'*.{extension}')
    else:
        items = Path(path).glob(f'*')
        
    items = list(items)
        
    p = random.choice(items)
    return p.as_posix()

# %%
# View random sample from the dataset
p = random_sample('baru\\validation\\BercakHitam')
orig = cv2.imread(p)
orig = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB) / 255.0
init_val = 100
columns = 3
rows = 3

fig=plt.figure(figsize=(15, 10))
for i in range(1, columns*rows +1):
    quality=init_val - (i-1) * 8
    img = compute_ela_cv(path=p, quality=quality)
    if i == 1:
        img = orig.copy()
    ax = fig.add_subplot(rows, columns, i) 
    ax.title.set_text(f'q: {quality}')
    plt.imshow(img)
plt.show()

# %%
from tensorflow.keras.applications import MobileNetV2, NASNetMobile, ResNet50V2, EfficientNetB0, DenseNet121
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Input, MaxPool2D
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import seaborn as sns
from tensorflow.keras.applications import EfficientNetV2L
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       3 from tensorflow.keras.layers import Input, MaxPool2D
#       4 import numpy as np
# ----> 5 import matplotlib.pyplot as plt
#       6 import pathlib
#       7 import seaborn as sns
#
# File D:\Anaconda3\lib\site-packages\matplotlib\pyplot.py:57, in <module>
#      55 from matplotlib import docstring
#      56 from matplotlib.backend_bases import FigureCanvasBase, MouseButton
# ---> 57 from matplotlib.figure import Figure, figaspect
#      58 from matplotlib.gridspec import GridSpec, SubplotSpec
#      59 from matplotlib import rcParams, rcParamsDefault, get_backend, rcParamsOrig
#
# File D:\Anaconda3\lib\site-packages\matplotlib\figure.py:25, in <module>
#      22 import numpy as np
#      24 import matplotlib as mpl
# ---> 25 from matplotlib import _blocking_input, docstring, projections
#      26 from matplotlib.artist import (
#      27     Artist, allow_rasterization, _finalize_rasterization)
#      28 from matplotlib.backend_bases import (
#      29     FigureCanvasBase, NonGuiException, MouseButton, _get_renderer)
#
# File D:\Anaconda3\lib\site-packages\matplotlib\projections\__init__.py:55, in <module>
#       1 """
#       2 Non-separable transforms that map from data space to screen space.
#       3
#    (...)
#      52 `matplotlib.projections.polar` may also be of interest.
#      53 """
# ---> 55 from .. import axes, docstring
#      56 from .geo import AitoffAxes, HammerAxes, LambertAxes, MollweideAxes
#      57 from .polar import PolarAxes
#
# File D:\Anaconda3\lib\site-packages\matplotlib\axes\__init__.py:1, in <module>
# ----> 1 from ._subplots import *
#       2 from ._axes import *
#
# File D:\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py:3, in <module>
#       1 import matplotlib as mpl
#       2 from matplotlib import _api, cbook
# ----> 3 from matplotlib.axes._axes import Axes
#       4 from matplotlib.gridspec import GridSpec, SubplotSpec
#       7 class SubplotBase:
#
# File D:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:36, in <module>
#      33 from matplotlib import _api, _preprocess_data, rcParams
#      34 from matplotlib.axes._base import (
#      35     _AxesBase, _TransformedBoundsLocator, _process_plot_format)
# ---> 36 from matplotlib.axes._secondary_axes import SecondaryAxis
#      37 from matplotlib.container import BarContainer, ErrorbarContainer, StemContainer
#      39 _log = logging.getLogger(__name__)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:982, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:925, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1423, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1395, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1522, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:142, in _path_stat(path)
#
# KeyboardInterrupt:

# %%
TRAINING_DIR = "baru//Training"
VALIDATION_DIR = "baru//validation"

train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    fill_mode='nearest'
)

train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                    class_mode='categorical',
                                                    target_size=(224, 224))

validation_datagen = ImageDataGenerator(
    rescale=1.0/255
)
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                        class_mode='categorical',
                                                        target_size=(224, 224))
# Out:
# Found 4203 images belonging to 5 classes.
# Found 968 images belonging to 5 classes.

# %%
print(train_generator.class_indices)
# Out:
# {'BercakHitam': 0, 'BukanDaunAnggur': 1, 'DaunSehat': 2, 'HawarDaun': 3, 'KaratDaun': 4}

# %%
# Pretrain Model
pre_trained_model = ResNet50V2(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

for layer in pre_trained_model.layers:
    layer.trainable = False

# %%
model = tf.keras.Sequential([
    pre_trained_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(5, activation='softmax')
])

# %%
from tensorflow.keras.utils import plot_model

# visualisasi model
plot_model(model, to_file='model.png', show_shapes=True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 24,688,133
# Trainable params: 1,123,333
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
int_lr = 0.0001
num_epochs = 100

# Early Stopping
earlystop_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# Model Checkpoint
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

# Compile and Training
optimizer = tf.optimizers.Adam(learning_rate=int_lr)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(
    train_generator,
    epochs=num_epochs,
    validation_data=validation_generator,
    callbacks=[earlystop_callback, checkpoint_callback]
)
# Out:
# Epoch 1/100
# 132/132 [==============================] - ETA: 0s - loss: 0.9564 - accuracy: 0.6039
# Epoch 1: val_accuracy improved from -inf to 0.73347, saving model to best_weights.h5
# 132/132 [==============================] - 370s 3s/step - loss: 0.9564 - accuracy: 0.6039 - val_loss: 0.6789 - val_accuracy: 0.7335
# Epoch 2/100
# 132/132 [==============================] - ETA: 0s - loss: 0.6020 - accuracy: 0.7554
# Epoch 2: val_accuracy improved from 0.73347 to 0.75103, saving model to best_weights.h5
# 132/132 [==============================] - 355s 3s/step - loss: 0.6020 - accuracy: 0.7554 - val_loss: 0.6211 - val_accuracy: 0.7510
# Epoch 3/100
# 132/132 [==============================] - ETA: 0s - loss: 0.4864 - accuracy: 0.8063
# Epoch 3: val_accuracy improved from 0.75103 to 0.75517, saving model to best_weights.h5
# 132/132 [==============================] - 357s 3s/step - loss: 0.4864 - accuracy: 0.8063 - val_loss: 0.5901 - val_accuracy: 0.7552
# Epoch 4/100
# 132/132 [==============================] - ETA: 0s - loss: 0.4252 - accuracy: 0.8377
# Epoch 4: val_accuracy improved from 0.75517 to 0.77479, saving model to best_weights.h5
# 132/132 [==============================] - 342s 3s/step - loss: 0.4252 - accuracy: 0.8377 - val_loss: 0.5379 - val_accuracy: 0.7748
# Epoch 5/100
# 132/132 [==============================] - ETA: 0s - loss: 0.3588 - accuracy: 0.8627
# Epoch 5: val_accuracy improved from 0.77479 to 0.79029, saving model to best_weights.h5
# 132/132 [==============================] - 364s 3s/step - loss: 0.3588 - accuracy: 0.8627 - val_loss: 0.4901 - val_accuracy: 0.7903
# Epoch 6/100
# 132/132 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.8837
# Epoch 6: val_accuracy improved from 0.79029 to 0.80579, saving model to best_weights.h5
# 132/132 [==============================] - 369s 3s/step - loss: 0.3137 - accuracy: 0.8837 - val_loss: 0.4524 - val_accuracy: 0.8058
# Epoch 7/100
# 132/132 [==============================] - ETA: 0s - loss: 0.2688 - accuracy: 0.8972
# Epoch 7: val_accuracy improved from 0.80579 to 0.81715, saving model to best_weights.h5
# 132/132 [==============================] - 415s 3s/step - loss: 0.2688 - accuracy: 0.8972 - val_loss: 0.4368 - val_accuracy: 0.8171
# Epoch 8/100
# 132/132 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.9163
# Epoch 8: val_accuracy improved from 0.81715 to 0.82541, saving model to best_weights.h5
# 132/132 [==============================] - 395s 3s/step - loss: 0.2312 - accuracy: 0.9163 - val_loss: 0.4363 - val_accuracy: 0.8254
# Epoch 9/100
# 132/132 [==============================] - ETA: 0s - loss: 0.2031 - accuracy: 0.9281
# Epoch 9: val_accuracy did not improve from 0.82541
# 132/132 [==============================] - 383s 3s/step - loss: 0.2031 - accuracy: 0.9281 - val_loss: 0.4431 - val_accuracy: 0.8254
# Epoch 10/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1762 - accuracy: 0.9405
# Epoch 10: val_accuracy improved from 0.82541 to 0.83678, saving model to best_weights.h5
# 132/132 [==============================] - 365s 3s/step - loss: 0.1762 - accuracy: 0.9405 - val_loss: 0.4129 - val_accuracy: 0.8368
# Epoch 11/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9510
# Epoch 11: val_accuracy did not improve from 0.83678
# 132/132 [==============================] - 363s 3s/step - loss: 0.1500 - accuracy: 0.9510 - val_loss: 0.4331 - val_accuracy: 0.8337
# Epoch 12/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1308 - accuracy: 0.9562
# Epoch 12: val_accuracy did not improve from 0.83678
# 132/132 [==============================] - 354s 3s/step - loss: 0.1308 - accuracy: 0.9562 - val_loss: 0.4101 - val_accuracy: 0.8316
# Epoch 13/100
# 132/132 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9631
# Epoch 13: val_accuracy improved from 0.83678 to 0.84504, saving model to best_weights.h5
# 132/132 [==============================] - 504s 4s/step - loss: 0.1152 - accuracy: 0.9631 - val_loss: 0.3755 - val_accuracy: 0.8450
# Epoch 14/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.9736
# Epoch 14: val_accuracy improved from 0.84504 to 0.85640, saving model to best_weights.h5
# 132/132 [==============================] - 565s 4s/step - loss: 0.0902 - accuracy: 0.9736 - val_loss: 0.4069 - val_accuracy: 0.8564
# Epoch 15/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9772
# Epoch 15: val_accuracy did not improve from 0.85640
# 132/132 [==============================] - 550s 4s/step - loss: 0.0817 - accuracy: 0.9772 - val_loss: 0.3993 - val_accuracy: 0.8523
# Epoch 16/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9807
# Epoch 16: val_accuracy improved from 0.85640 to 0.86674, saving model to best_weights.h5
# 132/132 [==============================] - 499s 4s/step - loss: 0.0688 - accuracy: 0.9807 - val_loss: 0.3570 - val_accuracy: 0.8667
# Epoch 17/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9836
# Epoch 17: val_accuracy improved from 0.86674 to 0.86880, saving model to best_weights.h5
# 132/132 [==============================] - 510s 4s/step - loss: 0.0610 - accuracy: 0.9836 - val_loss: 0.3419 - val_accuracy: 0.8688
# Epoch 18/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9888
# Epoch 18: val_accuracy did not improve from 0.86880
# 132/132 [==============================] - 537s 4s/step - loss: 0.0518 - accuracy: 0.9888 - val_loss: 0.4709 - val_accuracy: 0.8554
# Epoch 19/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0402 - accuracy: 0.9910
# Epoch 19: val_accuracy did not improve from 0.86880
# 132/132 [==============================] - 521s 4s/step - loss: 0.0402 - accuracy: 0.9910 - val_loss: 0.4364 - val_accuracy: 0.8657
# Epoch 20/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9941
# Epoch 20: val_accuracy did not improve from 0.86880
# 132/132 [==============================] - 565s 4s/step - loss: 0.0311 - accuracy: 0.9941 - val_loss: 0.4216 - val_accuracy: 0.8595
# Epoch 21/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0334 - accuracy: 0.9929
# Epoch 21: val_accuracy improved from 0.86880 to 0.87087, saving model to best_weights.h5
# 132/132 [==============================] - 511s 4s/step - loss: 0.0334 - accuracy: 0.9929 - val_loss: 0.3901 - val_accuracy: 0.8709
# Epoch 22/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9929
# Epoch 22: val_accuracy did not improve from 0.87087
# 132/132 [==============================] - 426s 3s/step - loss: 0.0290 - accuracy: 0.9929 - val_loss: 0.5697 - val_accuracy: 0.8306
# Epoch 23/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9967
# Epoch 23: val_accuracy improved from 0.87087 to 0.88017, saving model to best_weights.h5
# 132/132 [==============================] - 386s 3s/step - loss: 0.0204 - accuracy: 0.9967 - val_loss: 0.3821 - val_accuracy: 0.8802
# Epoch 24/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9952
# Epoch 24: val_accuracy did not improve from 0.88017
# 132/132 [==============================] - 442s 3s/step - loss: 0.0211 - accuracy: 0.9952 - val_loss: 0.5094 - val_accuracy: 0.8543
# Epoch 25/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9988
# Epoch 25: val_accuracy improved from 0.88017 to 0.88326, saving model to best_weights.h5
# 132/132 [==============================] - 424s 3s/step - loss: 0.0156 - accuracy: 0.9988 - val_loss: 0.4128 - val_accuracy: 0.8833
# Epoch 26/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9983
# Epoch 26: val_accuracy did not improve from 0.88326
# 132/132 [==============================] - 407s 3s/step - loss: 0.0133 - accuracy: 0.9983 - val_loss: 0.4750 - val_accuracy: 0.8688
# Epoch 27/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9974
# Epoch 27: val_accuracy did not improve from 0.88326
# 132/132 [==============================] - 436s 3s/step - loss: 0.0151 - accuracy: 0.9974 - val_loss: 0.4436 - val_accuracy: 0.8760
# Epoch 28/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9976
# Epoch 28: val_accuracy improved from 0.88326 to 0.88946, saving model to best_weights.h5
# 132/132 [==============================] - 419s 3s/step - loss: 0.0117 - accuracy: 0.9976 - val_loss: 0.4310 - val_accuracy: 0.8895
# Epoch 29/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9974
# Epoch 29: val_accuracy did not improve from 0.88946
# 132/132 [==============================] - 354s 3s/step - loss: 0.0129 - accuracy: 0.9974 - val_loss: 0.4197 - val_accuracy: 0.8864
# Epoch 30/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9993
# Epoch 30: val_accuracy did not improve from 0.88946
# 132/132 [==============================] - 367s 3s/step - loss: 0.0088 - accuracy: 0.9993 - val_loss: 0.4709 - val_accuracy: 0.8781
# Epoch 31/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9979
# Epoch 31: val_accuracy did not improve from 0.88946
# 132/132 [==============================] - 355s 3s/step - loss: 0.0096 - accuracy: 0.9979 - val_loss: 0.5178 - val_accuracy: 0.8760
# Epoch 32/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9993
# Epoch 32: val_accuracy did not improve from 0.88946
# 132/132 [==============================] - 373s 3s/step - loss: 0.0079 - accuracy: 0.9993 - val_loss: 0.6072 - val_accuracy: 0.8605
# Epoch 33/100
# 132/132 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9976Restoring model weights from the end of the best epoch: 28.
#
# Epoch 33: val_accuracy did not improve from 0.88946
# 132/132 [==============================] - 409s 3s/step - loss: 0.0106 - accuracy: 0.9976 - val_loss: 0.4657 - val_accuracy: 0.8843
# Epoch 33: early stopping

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Membuat list nilai loss dan akurasi dari model
train_loss = model.history.history['loss']
val_loss = model.history.history['val_loss']
train_acc = model.history.history['accuracy']
val_acc = model.history.history['val_accuracy']

# Membuat plot
fig, ax = plt.subplots(1,2, figsize=(17,5))
sns.set_style("darkgrid")

# Plot loss
ax[0].plot(train_loss, label='Training Loss')
ax[0].plot(val_loss, label='Validation Loss')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Loss')
ax[0].legend()

# Plot accuracy
ax[1].plot(train_acc, label='Training Accuracy')
ax[1].plot(val_acc, label='Validation Accuracy')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Accuracy')
ax[1].set_title('Accuracy')
ax[1].legend()

plt.show()

# %%
# Load weights
model.load_weights('best_weights.h5')

# Evaluate model on validation set
loss, accuracy = model.evaluate(validation_generator, verbose=1)
print('Validation Accuracy: {:.2%}'.format(accuracy))
print('Validation Loss: {:.2f}'.format(loss))
# Out:
# 31/31 [==============================] - 73s 2s/step - loss: 0.4310 - accuracy: 0.8895
# Validation Accuracy: 88.95%
# Validation Loss: 0.43

# %%
# Mendapatkan label yang sesuai dengan prediksi
class_labels = validation_generator.class_indices
class_labels = {v: k for k, v in class_labels.items()}

# %%
# Memuat bobot terbaik yang disimpan selama pelatihan
model.load_weights('best_weights.h5')

# Mengumpulkan semua prediksi dan label asli
y_pred = []
labels = []
for i in range(len(validation_generator)):
    batch_data, batch_labels = validation_generator[i]
    batch_pred = model.predict(batch_data)
    y_pred.extend(np.argmax(batch_pred, axis=1))
    labels.extend(np.argmax(batch_labels, axis=1))
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step

# %%
# Menghitung matriks kebingungan
cm = confusion_matrix(labels, y_pred)

# Menghitung akurasi
accuracy = np.sum(labels == y_pred) / len(labels)

# Membuat plot matriks kebingungan
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels.values(), yticklabels=class_labels.values())
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Mencetak laporan klasifikasi
classification_report_str = classification_report(labels, y_pred, target_names=class_labels.values())
print("Classification Report:")
print(classification_report_str)
# Out:
# Classification Report:
#                  precision    recall  f1-score   support
#
#     BercakHitam       0.88      0.68      0.77       204
# BukanDaunAnggur       1.00      0.99      0.99       189
#       DaunSehat       0.91      0.94      0.93       190
#       HawarDaun       0.93      0.97      0.95       197
#       KaratDaun       0.75      0.87      0.81       188
#
#        accuracy                           0.89       968
#       macro avg       0.89      0.89      0.89       968
#    weighted avg       0.89      0.89      0.89       968

# %%
export_dir = 'saved_model/'
tf.saved_model.save(model, export_dir)

# Convert SavedModel menjadi .tflite
converter = tf.lite.TFLiteConverter.from_saved_model(export_dir)
tflite_model = converter.convert()

tflite_model_file = pathlib.Path('boss92_resnet.tflite')
tflite_model_file.write_bytes(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: saved_model/assets
# INFO:tensorflow:Assets written to: saved_model/assets
# 98596980
